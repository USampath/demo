# %%
"""
importing required libraries using import function
pandas and numpy for reading dataset and data analysis
and matplotlib.pyplot and seaborn for data visualisation
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading dataset using pd.read_csv function to read an csv file , by giving file location and filename.csv
# it is california housing data set which gives information about housing type of blocks , rooms , people their income and housevalue

df = pd.read_csv("Downloads/housing (1).csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
"""
There are 10 variables and 20640 rows and variable data types are shown in flower brackets
Data consists of 20640 rows and 10 features:

1.longitude: A measure of how far west a house is; a higher value is farther west {continuos}
2.latitude: A measure of how far north a house is; a higher value is farther north {Continuos}
3.housingMedianAge: Median age of a house within a block; a lower number is a newer building {Descrete}
4.totalRooms: Total number of rooms within a block{Descrete}
5.totalBedrooms: Total number of bedrooms within a block {Descrete}
6.population: Total number of people residing within a block{Descrete}
7.households: Total number of households, a group of people residing within a home unit, for a block{Descrete}
8.medianIncome: Median income for households within a block of houses{Continuos}
9.medianHouseValue: Median house value for households within a block {Descrete}
10.oceanProximity: Location of the house w.r.t ocean/sea {Nominal}
"""
# Out:
# '\nThere are 10 variables and 20640 rows and variable data types are shown in flower brackets\nData consists of 20640 rows and 10 features:\n\n1.longitude: A measure of how far west a house is; a higher value is farther west {continuos}\n2.latitude: A measure of how far north a house is; a higher value is farther north {Continuos}\n3.housingMedianAge: Median age of a house within a block; a lower number is a newer building {Descrete}\n4.totalRooms: Total number of rooms within a block{Descrete}\n5.totalBedrooms: Total number of bedrooms within a block {Descrete}\n6.population: Total number of people residing within a block{Descrete}\n7.households: Total number of households, a group of people residing within a home unit, for a block{Descrete}\n8.medianIncome: Median income for households within a block of houses{Continuos}\n9.medianHouseValue: Median house value for households within a block {Descrete}\n10.oceanProximity: Location of the house w.r.t ocean/sea {Nominal}\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
"""
1.What is the average median income of the data set and check the distribution of data using appropriate plots? 
  Please explain the distribution of the plot.
"""

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df['median_income'].hist()
# Out:
# <AxesSubplot:>

# %%
"""
Average of median income is 3.870
here i have used histogram plot to show the distribution of median_income 
histogram is the best graph to see distribution so ihave used hist()function to get histogram
median_income is not normally distributed and it is rightly skewed
"""
# Out:
# '\nAverage of median income is 3.870\nhere i have used histogram plot to show the distribution of median_income \nhistogram is the best graph to see distribution so ihave used hist()function to get histogram\n'

# %%
"""
2.Draw an appropriate plot for housing_median_age and explain your observations.
"""

# %%
df['housing_median_age'].hist()
# Out:
# <AxesSubplot:>

# %%
"""
3.Show with the help of visualization, how median_income and median_house_values are related?
"""

# %%
x = df.median_income
y = df.median_house_value
plt.scatter(x,y)

# %%
sns.lineplot(x="median_income", y="median_house_value", data=df)

plt.show()

# %%
x = df.median_income
y = df.median_house_value
plt.line(x,y)

# %%
#to see every feature and its distribution ,using df.hist function to show all histogram plots of every variable
df.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %%
"""
 Above plot shows histograms of numerical features of data set
 Housing median age looks to be me normal distribution
 and all other features other than latittude and longitude are skewed and they are more or less slightly right skewed
"""

# %%
"""
10.Please create a new column named total_bedroom_size. If size 10 or less. It should be quoted as small. 
   If the size is 11 or more but 1000 less, it should be medium, otherwise, it should be large.
"""

# %%
total_bedroom_size = []
for row in df['total_bedrooms']:
        if row < 11.0 :    total_bedroom_size.append('small')
        elif row < 1000.0:   total_bedroom_size.append('medium')
        elif row > 1000.0:  total_bedroom_size.append('large')
        
        
        else:           total_bedroom_size.append('NA')

# %%
df['total_bedroom_size'] = total_bedroom_size
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
